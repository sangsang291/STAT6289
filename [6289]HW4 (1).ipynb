# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df = pd.read_csv('~/Desktop/TSLA.csv',error_bad_lines=False)
print("Number of rows and columns:", df.shape)
df.head(5)
# Out:
# Number of rows and columns: (1328, 7)
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-09  51.816002  52.590000  51.358002  51.584000  51.584000  16670500
# 1  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 2  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 3  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 4  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

# %%
print(X_train.shape)
# Out:
# (740, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0644
# Epoch 2/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0169
# Epoch 3/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0129
# Epoch 4/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0128
# Epoch 5/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0120
# Epoch 6/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0111
# Epoch 7/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0116
# Epoch 8/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0107
# Epoch 9/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0103
# Epoch 10/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0099
# Epoch 11/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0104
# Epoch 12/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0107
# Epoch 13/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0089
# Epoch 14/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0101
# Epoch 15/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0090
# Epoch 16/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0087
# Epoch 17/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0080
# Epoch 18/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0084
# Epoch 19/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0080
# Epoch 20/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0073
# Epoch 21/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0083
# Epoch 22/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0090
# Epoch 23/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0087
# Epoch 24/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0070
# Epoch 25/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0076
# Epoch 26/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0064
# Epoch 27/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0070
# Epoch 28/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0063
# Epoch 29/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0078
# Epoch 30/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0072
# Epoch 31/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0068
# Epoch 32/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0064
# Epoch 33/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0058
# Epoch 34/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0063
# Epoch 35/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0072
# Epoch 36/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0070
# Epoch 37/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0055
# Epoch 38/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0052
# Epoch 39/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0050
# Epoch 40/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0056
# Epoch 41/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0051
# Epoch 42/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0060
# Epoch 43/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0052
# Epoch 44/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0055
# Epoch 45/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0054
# Epoch 46/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0055
# Epoch 47/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0047
# Epoch 48/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0048
# Epoch 49/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0045
# Epoch 50/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0047
# Epoch 51/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0053
# Epoch 52/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0047
# Epoch 53/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0046
# Epoch 54/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0040
# Epoch 55/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0045
# Epoch 56/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0046
# Epoch 57/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0043
# Epoch 58/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0048
# Epoch 59/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0041
# Epoch 60/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0041
# Epoch 61/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0042
# Epoch 62/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0041
# Epoch 63/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0040
# Epoch 64/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0038
# Epoch 65/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0043
# Epoch 66/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0050
# Epoch 67/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0039
# Epoch 68/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0037
# Epoch 69/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0040
# Epoch 70/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0035
# Epoch 71/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0034
# Epoch 72/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0034
# Epoch 73/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0031
# Epoch 74/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0036
# Epoch 75/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0036
# Epoch 76/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0034
# Epoch 77/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0038
# Epoch 78/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0039
# Epoch 79/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0034
# Epoch 80/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0036
# Epoch 81/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0037
# Epoch 82/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0033
# Epoch 83/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0029
# Epoch 84/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0034
# Epoch 85/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0034
# Epoch 86/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0039
# Epoch 87/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0033
# Epoch 88/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0037
# Epoch 89/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0031
# Epoch 90/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0031
# Epoch 91/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0034
# Epoch 92/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0032
# Epoch 93/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0029
# Epoch 94/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0034
# Epoch 95/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0031
# Epoch 96/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0030
# Epoch 97/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0030
# Epoch 98/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0029
# Epoch 99/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0030
# Epoch 100/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0035

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)
# Out:
# (528, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualising the results
plt.plot(df.loc[800:, "Date"],dataset_test.values, color = "red", label = "Real TESLA Stock Price")
plt.plot(df.loc[800:, "Date"],predicted_stock_price, color = "blue", label = "Predicted TESLA Stock Price")
plt.xticks(np.arange(0,542,58))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df = pd.read_csv('~/Desktop/TSLA.csv',error_bad_lines=False)
print('Number of rows and columns:', df.shape)
df.head(5)
# Out:
# Number of rows and columns: (1328, 7)
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-09  51.816002  52.590000  51.358002  51.584000  51.584000  16670500
# 1  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 2  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 3  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 4  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

# %%
print(X_train.shape)
# Out:
# (740, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# %%
model1 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model1.add(Dropout(0.5))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.5))
# Adding a third LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.5))
# Adding a fourth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50))
model1.add(Dropout(0.5))
# Adding the output layer
model1.add(Dense(units = 1))

# %%
model2 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model2.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True))
model2.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True))
model2.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50))
model2.add(Dropout(0.2))
# Adding the output layer
model2.add(Dense(units = 1))

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
model2.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
model1.fit(X_train, y_train, epochs = 100, batch_size = 32)
model2.fit(X_train, y_train, epochs = 100, batch_size = 64)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0698
# Epoch 2/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0177
# Epoch 3/100
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0133
# Epoch 4/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0117
# Epoch 5/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0115
# Epoch 6/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0114
# Epoch 7/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0105
# Epoch 8/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0118
# Epoch 9/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0100
# Epoch 10/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0096
# Epoch 11/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0095
# Epoch 12/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0079
# Epoch 13/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0089
# Epoch 14/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0094
# Epoch 15/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0082
# Epoch 16/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0077
# Epoch 17/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0077
# Epoch 18/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0072
# Epoch 19/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0075
# Epoch 20/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0070
# Epoch 21/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0071
# Epoch 22/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0063
# Epoch 23/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0076
# Epoch 24/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0062
# Epoch 25/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0062
# Epoch 26/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0066
# Epoch 27/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0063
# Epoch 28/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0060
# Epoch 29/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0072
# Epoch 30/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0064
# Epoch 31/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0069
# Epoch 32/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0063
# Epoch 33/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0053
# Epoch 34/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0051
# Epoch 35/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0053
# Epoch 36/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0050
# Epoch 37/100
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0049
# Epoch 38/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0052
# Epoch 39/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0049
# Epoch 40/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0059
# Epoch 41/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0048
# Epoch 42/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0042
# Epoch 43/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0045
# Epoch 44/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0044
# Epoch 45/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0041
# Epoch 46/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0048
# Epoch 47/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0049
# Epoch 48/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0038
# Epoch 49/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0037
# Epoch 50/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0041
# Epoch 51/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0040
# Epoch 52/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0041
# Epoch 53/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0041
# Epoch 54/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0042
# Epoch 55/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0045
# Epoch 56/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0041
# Epoch 57/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0036
# Epoch 58/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0037
# Epoch 59/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0037
# Epoch 60/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0042
# Epoch 61/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0040
# Epoch 62/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0033
# Epoch 63/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0033
# Epoch 64/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0038
# Epoch 65/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0038
# Epoch 66/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0036
# Epoch 67/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0039
# Epoch 68/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0042
# Epoch 69/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0039
# Epoch 70/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0037
# Epoch 71/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0036
# Epoch 72/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0035
# Epoch 73/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0037
# Epoch 74/100
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0031
# Epoch 75/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0031
# Epoch 76/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0034
# Epoch 77/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0034
# Epoch 78/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0034
# Epoch 79/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0038
# Epoch 80/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0031
# Epoch 81/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0032
# Epoch 82/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0034
# Epoch 83/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0031
# Epoch 84/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0036
# Epoch 85/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0036
# Epoch 86/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0029
# Epoch 87/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0034
# Epoch 88/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0030
# Epoch 89/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0034
# Epoch 90/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0039
# Epoch 91/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0034
# Epoch 92/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0032
# Epoch 93/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0030
# Epoch 94/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0029
# Epoch 95/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0030
# Epoch 96/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0028
# Epoch 97/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0030
# Epoch 98/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0030
# Epoch 99/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0026
# Epoch 100/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0030
# Epoch 1/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0756
# Epoch 2/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0276
# Epoch 3/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0217
# Epoch 4/100
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0234
# Epoch 5/100
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0197
# Epoch 6/100
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0177
# Epoch 7/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0173
# Epoch 8/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0170
# Epoch 9/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0163
# Epoch 10/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0161
# Epoch 11/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0146
# Epoch 12/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0142
# Epoch 13/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0171
# Epoch 14/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0140
# Epoch 15/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0141
# Epoch 16/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0124
# Epoch 17/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0134
# Epoch 18/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0127
# Epoch 19/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0122
# Epoch 20/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0114
# Epoch 21/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0127
# Epoch 22/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0115
# Epoch 23/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0113
# Epoch 24/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0107
# Epoch 25/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0107
# Epoch 26/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0110
# Epoch 27/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0103
# Epoch 28/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0116
# Epoch 29/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0100
# Epoch 30/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0101
# Epoch 31/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0096
# Epoch 32/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0091
# Epoch 33/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0085
# Epoch 34/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0101
# Epoch 35/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0099
# Epoch 36/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0082
# Epoch 37/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0090
# Epoch 38/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0088
# Epoch 39/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0081
# Epoch 40/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0093
# Epoch 41/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0086
# Epoch 42/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0084
# Epoch 43/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0089
# Epoch 44/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0084
# Epoch 45/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0075
# Epoch 46/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0077
# Epoch 47/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0074
# Epoch 48/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0080
# Epoch 49/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0095
# Epoch 50/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0064
# Epoch 51/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0067
# Epoch 52/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0074
# Epoch 53/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0064
# Epoch 54/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0065
# Epoch 55/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0062
# Epoch 56/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0064
# Epoch 57/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0068
# Epoch 58/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0065
# Epoch 59/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0063
# Epoch 60/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0067
# Epoch 61/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0064
# Epoch 62/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0065
# Epoch 63/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0059
# Epoch 64/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0068
# Epoch 65/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0069
# Epoch 66/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0068
# Epoch 67/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0068
# Epoch 68/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0067
# Epoch 69/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0059
# Epoch 70/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0062
# Epoch 71/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0052
# Epoch 72/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0054
# Epoch 73/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0058
# Epoch 74/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0053
# Epoch 75/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0060
# Epoch 76/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0062
# Epoch 77/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0057
# Epoch 78/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0059
# Epoch 79/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0054
# Epoch 80/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0054
# Epoch 81/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0055
# Epoch 82/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0052
# Epoch 83/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0050
# Epoch 84/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0057
# Epoch 85/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0048
# Epoch 86/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0053
# Epoch 87/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0055
# Epoch 88/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0050
# Epoch 89/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0050
# Epoch 90/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0048
# Epoch 91/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0049
# Epoch 92/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0051
# Epoch 93/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0047
# Epoch 94/100
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0052
# Epoch 95/100
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0046
# Epoch 96/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0048
# Epoch 97/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0047
# Epoch 98/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0057
# Epoch 99/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0045
# Epoch 100/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0049
# Epoch 1/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0951
# Epoch 2/100
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0263
# Epoch 3/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0178
# Epoch 4/100
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0139
# Epoch 5/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.0130
# Epoch 6/100
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0130
# Epoch 7/100
# 12/12 [==============================] - 1s 83ms/step - loss: 0.0109
# Epoch 8/100
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0119
# Epoch 9/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0109
# Epoch 10/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0109
# Epoch 11/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0116
# Epoch 12/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0106
# Epoch 13/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0114
# Epoch 14/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0108
# Epoch 15/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0102
# Epoch 16/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0096
# Epoch 17/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0099
# Epoch 18/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0101
# Epoch 19/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0090
# Epoch 20/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0108
# Epoch 21/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0101
# Epoch 22/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0099
# Epoch 23/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0092
# Epoch 24/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0087
# Epoch 25/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0091
# Epoch 26/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0077
# Epoch 27/100
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0078
# Epoch 28/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0083
# Epoch 29/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0081
# Epoch 30/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0071
# Epoch 31/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0078
# Epoch 32/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0082
# Epoch 33/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0071
# Epoch 34/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0071
# Epoch 35/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0065
# Epoch 36/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0065
# Epoch 37/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0072
# Epoch 38/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0075
# Epoch 39/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0075
# Epoch 40/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0072
# Epoch 41/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0067
# Epoch 42/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0066
# Epoch 43/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0065
# Epoch 44/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0066
# Epoch 45/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0061
# Epoch 46/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0060
# Epoch 47/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0063
# Epoch 48/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0059
# Epoch 49/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0069
# Epoch 50/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.0076
# Epoch 51/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0073
# Epoch 52/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0056
# Epoch 53/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0058
# Epoch 54/100
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0054
# Epoch 55/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0055
# Epoch 56/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0054
# Epoch 57/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0053
# Epoch 58/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0052
# Epoch 59/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0052
# Epoch 60/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0052
# Epoch 61/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0052
# Epoch 62/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0051
# Epoch 63/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0050
# Epoch 64/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0048
# Epoch 65/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0050
# Epoch 66/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0051
# Epoch 67/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0044
# Epoch 68/100
# 12/12 [==============================] - 1s 95ms/step - loss: 0.0048
# Epoch 69/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0042
# Epoch 70/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0044
# Epoch 71/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0045
# Epoch 72/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0045
# Epoch 73/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0048
# Epoch 74/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0041
# Epoch 75/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0048
# Epoch 76/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0042
# Epoch 77/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0048
# Epoch 78/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0050
# Epoch 79/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0048
# Epoch 80/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0046
# Epoch 81/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0041
# Epoch 82/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0043
# Epoch 83/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0040
# Epoch 84/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0041
# Epoch 85/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0044
# Epoch 86/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0042
# Epoch 87/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0041
# Epoch 88/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.0037
# Epoch 89/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0046
# Epoch 90/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0039
# Epoch 91/100
# 12/12 [==============================] - 1s 91ms/step - loss: 0.0040
# Epoch 92/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0044
# Epoch 93/100
# 12/12 [==============================] - 1s 90ms/step - loss: 0.0041
# Epoch 94/100
# 12/12 [==============================] - 1s 89ms/step - loss: 0.0040
# Epoch 95/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0043
# Epoch 96/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0039
# Epoch 97/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0034
# Epoch 98/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.0037
# Epoch 99/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.0034
# Epoch 100/100
# 12/12 [==============================] - 1s 85ms/step - loss: 0.0041

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)
# Out:
# (528, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price1 = model1.predict(X_test)
predicted_stock_price1 = sc.inverse_transform(predicted_stock_price1)

# %%
predicted_stock_price2 = model2.predict(X_test)
predicted_stock_price2 = sc.inverse_transform(predicted_stock_price2)

# %%
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
a = df.loc[800:,'Date']
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price with orgin')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price1, color = 'yellow', label = 'Predicted TESLA Stock Price with 0.5 dropout')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price2, color = 'green', label = 'Predicted TESLA Stock Price with 64 batch size')
plt.xticks(np.arange(0,528,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df = pd.read_csv('~/Desktop/TSLA.csv',error_bad_lines=False)
print('Number of rows and columns:', df.shape)
df.head(5)
# Out:
# Number of rows and columns: (1328, 7)
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-07-09  51.816002  52.590000  51.358002  51.584000  51.584000  16670500
# 1  2015-07-10  52.444000  52.599998  51.563999  51.830002  51.830002  13054500
# 2  2015-07-13  52.450001  52.509998  51.209999  52.431999  52.431999  14801500
# 3  2015-07-14  52.419998  53.198002  52.102001  53.130001  53.130001   9538000
# 4  2015-07-15  53.348000  53.498001  52.416000  52.627998  52.627998  10108000

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

# %%
print(X_train.shape)
# Out:
# (740, 60, 1)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# %%
model1 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model1.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50))
model1.add(Dropout(0.2))
# Adding the output layer
model1.add(Dense(units = 1))

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model1.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
model1.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0667
# Epoch 2/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0157
# Epoch 3/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0132
# Epoch 4/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0138
# Epoch 5/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0127
# Epoch 6/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0115
# Epoch 7/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0114
# Epoch 8/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0107
# Epoch 9/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0111
# Epoch 10/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0098
# Epoch 11/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0103
# Epoch 12/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0089
# Epoch 13/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0096
# Epoch 14/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0099
# Epoch 15/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0090
# Epoch 16/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0089
# Epoch 17/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0086
# Epoch 18/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0075
# Epoch 19/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0077
# Epoch 20/100
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0077
# Epoch 21/100
# 24/24 [==============================] - 2s 103ms/step - loss: 0.0085
# Epoch 22/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0069
# Epoch 23/100
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0082
# Epoch 24/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0067
# Epoch 25/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0068
# Epoch 26/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0064
# Epoch 27/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0062
# Epoch 28/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0066
# Epoch 29/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0061
# Epoch 30/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0078
# Epoch 31/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0063
# Epoch 32/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0061
# Epoch 33/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0062
# Epoch 34/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0061
# Epoch 35/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0066
# Epoch 36/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0063
# Epoch 37/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0060
# Epoch 38/100
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0055
# Epoch 39/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0054
# Epoch 40/100
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0059
# Epoch 41/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0051
# Epoch 42/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0047
# Epoch 43/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0054
# Epoch 44/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0048
# Epoch 45/100
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0048
# Epoch 46/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0052
# Epoch 47/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0046
# Epoch 48/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0044
# Epoch 49/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0046
# Epoch 50/100
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0052
# Epoch 51/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0048
# Epoch 52/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0049
# Epoch 53/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0041
# Epoch 54/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0041
# Epoch 55/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0043
# Epoch 56/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0037
# Epoch 57/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0040
# Epoch 58/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0042
# Epoch 59/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0039
# Epoch 60/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0040
# Epoch 61/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0040
# Epoch 62/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0039
# Epoch 63/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0036
# Epoch 64/100
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0036
# Epoch 65/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0040
# Epoch 66/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0042
# Epoch 67/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0038
# Epoch 68/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0040
# Epoch 69/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0041
# Epoch 70/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0035
# Epoch 71/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0035
# Epoch 72/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0035
# Epoch 73/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0032
# Epoch 74/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0032
# Epoch 75/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0035
# Epoch 76/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0033
# Epoch 77/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0040
# Epoch 78/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0036
# Epoch 79/100
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0036
# Epoch 80/100
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0038
# Epoch 81/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0034
# Epoch 82/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0032
# Epoch 83/100
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0031
# Epoch 84/100
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0036
# Epoch 85/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0031
# Epoch 86/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0030
# Epoch 87/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0033
# Epoch 88/100
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0032
# Epoch 89/100
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0037
# Epoch 90/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0032
# Epoch 91/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0030
# Epoch 92/100
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0032
# Epoch 93/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0032
# Epoch 94/100
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0031
# Epoch 95/100
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0030
# Epoch 96/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0033
# Epoch 97/100
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0029
# Epoch 98/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0027
# Epoch 99/100
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0029
# Epoch 100/100
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0030
# Epoch 1/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0730
# Epoch 2/100
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0188
# Epoch 3/100
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0187
# Epoch 4/100
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0135
# Epoch 5/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0144
# Epoch 6/100
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0131
# Epoch 7/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0155
# Epoch 8/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0132
# Epoch 9/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0121
# Epoch 10/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0124
# Epoch 11/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0109
# Epoch 12/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0114
# Epoch 13/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0104
# Epoch 14/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0101
# Epoch 15/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0110
# Epoch 16/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0092
# Epoch 17/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0092
# Epoch 18/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0091
# Epoch 19/100
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0091
# Epoch 20/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0080
# Epoch 21/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0084
# Epoch 22/100
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0076
# Epoch 23/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0074
# Epoch 24/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0082
# Epoch 25/100
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0076
# Epoch 26/100
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0078
# Epoch 27/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0078
# Epoch 28/100
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0071
# Epoch 29/100
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0070
# Epoch 30/100
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0071
# Epoch 31/100
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0074
# Epoch 32/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0064
# Epoch 33/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0061
# Epoch 34/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0071
# Epoch 35/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0069
# Epoch 36/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0068
# Epoch 37/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0051
# Epoch 38/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0063
# Epoch 39/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0051
# Epoch 40/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0055
# Epoch 41/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0061
# Epoch 42/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0060
# Epoch 43/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0049
# Epoch 44/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0046
# Epoch 45/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0050
# Epoch 46/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0049
# Epoch 47/100
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0049
# Epoch 48/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0050
# Epoch 49/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0056
# Epoch 50/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0048
# Epoch 51/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0047
# Epoch 52/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0046
# Epoch 53/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0049
# Epoch 54/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0046
# Epoch 55/100
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0046
# Epoch 56/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0039
# Epoch 57/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0048
# Epoch 58/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0043
# Epoch 59/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0048
# Epoch 60/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0037
# Epoch 61/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0038
# Epoch 62/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0042
# Epoch 63/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0041
# Epoch 64/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0043
# Epoch 65/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0042
# Epoch 66/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0041
# Epoch 67/100
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0039
# Epoch 68/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0037
# Epoch 69/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0034
# Epoch 70/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0039
# Epoch 71/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0037
# Epoch 72/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0036
# Epoch 73/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0037
# Epoch 74/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0039
# Epoch 75/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0037
# Epoch 76/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0038
# Epoch 77/100
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0043
# Epoch 78/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0037
# Epoch 79/100
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0039
# Epoch 80/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0045
# Epoch 81/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0037
# Epoch 82/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0039
# Epoch 83/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0034
# Epoch 84/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0034
# Epoch 85/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0033
# Epoch 86/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0032
# Epoch 87/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0035
# Epoch 88/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0036
# Epoch 89/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0040
# Epoch 90/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0030
# Epoch 91/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0037
# Epoch 92/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0035
# Epoch 93/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0034
# Epoch 94/100
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0036
# Epoch 95/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0036
# Epoch 96/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0032
# Epoch 97/100
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0030
# Epoch 98/100
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0031
# Epoch 99/100
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0034
# Epoch 100/100
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0031

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)
# Out:
# (528, 60, 1)

# %%
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price1 = model1.predict(X_test)
predicted_stock_price1 = sc.inverse_transform(predicted_stock_price1)

# %%
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price with 4 hidden layer')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price1, color = 'green', label = 'Predicted TESLA Stock Price with 6 hidden layer')
plt.xticks(np.arange(0,459,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df = pd.read_csv('~/Desktop/TSLA.csv',error_bad_lines=False)
print('Number of rows and columns:', df.shape)
df.head(5)

# %%
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800,7):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

# %%
print(X_train.shape)

# %%
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)

# %%
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)

# %%
#predict
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
import copy
X_test2 = copy.deepcopy(X_test)
for i in range(14):
    X_temp = np.zeros([1,60,1])
    for j in range(58):
        X_temp[0][j][0]= X_test[-1][j+1][0]
    X_temp[0][59][0] = model.predict(X_test2[-1:])[0][0]
    X_test2 = np.vstack([X_test2,X_temp])

predicted_stock_price = model.predict(X_test2)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
predicted_stock_price.shape

# %%
# Visualising the results
c = ["2020/10/14","2020/10/15","2020/10/16","2020/10/17","2020/10/18","2020/10/19","2020/10/20","2020/10/21","2020/10/22","2020/10/23","2020/10/24","2020/10/25","2020/10/26","2020/10/27","2020/10/28"]
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
plt.plot(df.loc[800:1325, 'Date'],predicted_stock_price[1:527], color = 'blue', label = 'Predicted TESLA Stock Price')
plt.plot(c,predicted_stock_price[527:], color = 'green', label = 'Predicted TESLA Stock Price')
plt.title('TESLA Stock Price Prediction')
plt.xticks(np.arange(0,542,60))
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
